# %%
from recipe_map import ArgParser, RecipeMap
import networkx as nx

# %%
prompt = """
Science Machine = Gold Nugget, 4 Log, 4 Rocks

Alchemy Engine = 4 Boards, 2 Cut Stone, 6 Gold Nugget

Boards = 4 Log
Cut Stone = 3 Rocks
Rope = 3 Cut Grass

Piggyback = 4 Pig Skin, 6 Silk, 2 Rope
Backpack = 4 Cut Grass, 4 Twigs
Lantern = 2 Light Bulb, 3 Twigs, 2 Rope

Pickaxe = 2 Twigs, 2 Flint
Opulent Pickaxe = 4 Twigs, 2 Gold Nugget
Shovel = 2 Twigs, 2 Flint
Axe = Twigs, Flint
Hammer = 3 Twigs, 3 Rocks, 6 Cut Grass

Ham Bat = Pig Skin, 2 Twigs, 2 Meat
Football Helmet = Pig Skin, Rope
Marble Suit = 6 Marble, 2 Rope


Village Raid Prep = Science Machine, Hammer, Backpack


Village Raid Prep
"""


argp = ArgParser(prompt)
dg = argp.parse_to_graph()
rm = RecipeMap(dg)
rm.evaluate(nx.layout.spring_layout)
# Out:
# e:\AnacondaDONT\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):
# e:\AnacondaDONT\lib\site-packages\networkx\drawing\nx_pylab.py:676: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if cb.iterable(node_size):  # many node sizes
# Materials Required:
#           Item  Count
# 0        Twigs      7
# 1    Cut Grass     10
# 3        Rocks      7
# 5          Log      4
# 6  Gold Nugget      1
# Crafting Order:
#                 Item  Count
# 2           Backpack      1
# 4             Hammer      1
# 7    Science Machine      1
# 8  Village Raid Prep      1
# 9               GOAL      0

# %%
prompt = """
Pickaxe = 2 Twigs, 2 Flint
Axe = Twigs, Flint
Shovel = 2 Twigs, 2 Flint

Hammer = 3 Twigs, 3 Rocks, 6 Cut Grass
Science Machine = Gold Nugget, 4 Log, 4 Rocks
Backpack = 4 Cut Grass, 4 Twigs

Alchemy Engine = 4 Boards, 2 Cut Stone, 6 Gold Nugget
Ham Bat = Pig Skin, 2 Twigs, 2 Meat
Football Helmet = Pig Skin, Rope

Lantern = 2 Light Bulb, 3 Twigs, 2 Rope
Opulent Pickaxe = 4 Twigs, 2 Gold Nugget

Rope = 3 Cut Grass

Marble Suit = 6 Marble, 2 Rope
Piggyback = 4 Pig Skin, 6 Silk, 2 Rope


Village Raid Prep = Science Machine, Hammer, Backpack
Cave Enter = Alchemy Engine, Ham Bat, Football Helmet, Lantern, Shovel

Cave Enter
"""


argp = ArgParser(prompt)
dg = argp.parse_to_graph()
rm = RecipeMap(dg)
rm.evaluate(nx.layout.spring_layout)
# Out:
# Materials Required:
#            Item  Count
# 0    Light Bulb      2
# 1          Meat      2
# 2      Pig Skin      2
# 3     Cut Stone      2
# 4        Boards      4
# 5   Gold Nugget      6
# 7     Cut Grass      9
# 10        Flint      2
# 11        Twigs      7
# Crafting Order:
#                Item  Count
# 6    Alchemy Engine      1
# 8              Rope      3
# 9   Football Helmet      1
# 12          Lantern      1
# 13          Ham Bat      1
# 14           Shovel      1
# 15       Cave Enter      1
# 16             GOAL      0

# %%
prompt = """
Science Machine = Gold Nugget, 4 Log, 4 Rocks

Alchemy Engine = 4 Boards, 2 Cut Stone, 6 Gold Nugget

Boards = 4 Log
Cut Stone = 3 Rocks
Rope = 3 Cut Grass

Piggyback = 4 Pig Skin, 6 Silk, 2 Rope
Backpack = 4 Cut Grass, 4 Twigs
Lantern = 2 Light Bulb, 3 Twigs, 2 Rope

Pickaxe = 2 Twigs, 2 Flint
Opulent Pickaxe = 4 Twigs, 2 Gold Nugget
Shovel = 2 Twigs, 2 Flint
Axe = Twigs, Flint
Hammer = 3 Twigs, 3 Rocks, 6 Cut Grass

Ham Bat = Pig Skin, 2 Twigs, 2 Meat
Football Helmet = Pig Skin, Rope
Marble Suit = 6 Marble, 2 Rope


Village Raid Prep = Science Machine, Hammer
Cave Enter = Alchemy Engine, Ham Bat, Football Helmet, Lantern, Shovel, Backpack

Magiluminescence = 2 Thulecite, 3 Nightmare Fuel, Yellow Gem
Thulecite Crown = 4 Thulecite, 4 Nightmare Fuel
Construction Amulet = 2 Thulecite, 3 Nightmare Fuel, Green Gem

Thulecite Club = 3 Living Log, 4 Thulecite, 4 Nightmare Fuel
Deconstruction Staff = 4 Nightmare Fuel, 2 Living Log, 2 Green Gem
Star Caller's Staff = 4 Nightmare Fuel, 2 Living Log, 2 Yellow Gem


Village Raid Prep
"""


argp = ArgParser(prompt)
dg = argp.parse_to_graph()
rm = RecipeMap(dg)
rm.evaluate(nx.layout.spring_layout)
# Out:
# Materials Required:
#           Item  Count
# 0        Twigs      3
# 1    Cut Grass      6
# 2        Rocks      7
# 4          Log      4
# 5  Gold Nugget      1
# Crafting Order:
#                 Item  Count
# 3             Hammer      1
# 6    Science Machine      1
# 7  Village Raid Prep      1
# 8               GOAL      0

# %%
prompt = """
Science Machine = Gold Nugget, 4 Log, 4 Rocks

Alchemy Engine = 4 Boards, 2 Cut Stone, 6 Gold Nugget

Boards = 4 Log
Cut Stone = 3 Rocks
Rope = 3 Cut Grass

Piggyback = 4 Pig Skin, 6 Silk, 2 Rope
Backpack = 4 Cut Grass, 4 Twigs
Lantern = 2 Light Bulb, 3 Twigs, 2 Rope

Pickaxe = 2 Twigs, 2 Flint
Opulent Pickaxe = 4 Twigs, 2 Gold Nugget
Shovel = 2 Twigs, 2 Flint
Axe = Twigs, Flint
Hammer = 3 Twigs, 3 Rocks, 6 Cut Grass

Ham Bat = Pig Skin, 2 Twigs, 2 Meat
Football Helmet = Pig Skin, Rope
Marble Suit = 6 Marble, 2 Rope

Beefalo Bell = 3 Gold Nugget, Flint
Saddle = 4 Beefalo Wool, 4 Pig Skin, 4 Gold Nugget
Salt Lick = 2 Boards, 4 Nitre
Beefalo Grooming Station = 2 Beefalo Wool, 4 Boards
Saddlehorn = 2 Twigs, 2 Bone Shards, Jet Feather

Village Raid Prep = Science Machine, Hammer
Cave Enter = Alchemy Engine, Ham Bat, Football Helmet, Lantern, Shovel, Backpack

Magiluminescence = 2 Thulecite, 3 Nightmare Fuel, Yellow Gem
Thulecite Crown = 4 Thulecite, 4 Nightmare Fuel
Construction Amulet = 2 Thulecite, 3 Nightmare Fuel, Green Gem

Thulecite Club = 3 Living Log, 4 Thulecite, 4 Nightmare Fuel
Deconstruction Staff = 4 Nightmare Fuel, 2 Living Log, 2 Green Gem
Star Caller's Staff = 4 Nightmare Fuel, 2 Living Log, 2 Yellow Gem

Prestihatitator = 4 Rabbit, 4 Boards, Top Hat
Top Hat = 6 Silk
Shadow Manipulator = 3 Living Log, Purple Gem, 7 Nightmare Fuel

Alarming Clock = 3 Time Pieces, 4 Marble, 8 Nightmare Fuel
Ageless Watch = Time Pieces, 2 Marble, Red Gem
Backstep Watch = Time Pieces, 2 Gold Nugget
Backtrek Watch = 2 Time Pieces, 2 Gold Nugget, Walrus Tusk
Clockmaker's Tools = Gold Nugget, Flint, 3 Twigs

WandaRush = Prestihatitator, Shadow Manipulator, Alarming Clock
WandaRush
"""

argp = ArgParser(prompt)
dg = argp.parse_to_graph()
rm = RecipeMap(dg)
rm.evaluate(nx.layout.spring_layout)
# Out:
# Materials Required:
#               Item  Count
# 0      Time Pieces      3
# 1       Purple Gem      1
# 2           Rabbit      4
# 3       Living Log      3
# 4   Nightmare Fuel     15
# 6           Marble      4
# 8             Silk      6
# 10             Log     16
# Crafting Order:
#                   Item  Count
# 5   Shadow Manipulator      1
# 7       Alarming Clock      1
# 9              Top Hat      1
# 11              Boards      4
# 12     Prestihatitator      1
# 13           WandaRush      1
# 14                GOAL      0
